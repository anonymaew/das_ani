# %% [markdown]
# ### DAS Geometry

# %%
# Import necessary dependencies
import os
import folium
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Define paths
file_path = os.path.join('..', 'geometry', 'geometry_offset.csv')

# %%
# Read CSV data
das_fiber_all = pd.read_csv(file_path)
das_fiber_all = das_fiber_all.drop(das_fiber_all.columns[0], axis=1)
das_fiber_all
# Out:
#       ch        long        lat
# 0    399 -122.181048  37.435539
# 1    400 -122.181101  37.435501
# 2    401 -122.181166  37.435452
# 3    402 -122.181247  37.435391
# 4    403 -122.181307  37.435347
# ..   ...         ...        ...
# 346  745 -122.205771  37.421297
# 347  746 -122.205873  37.421284
# 348  747 -122.205963  37.421272
# 349  748 -122.206011  37.421266
# 350  749 -122.206119  37.421252
#
# [351 rows x 3 columns]

# %%
# Compute center of map
center_lat = das_fiber_all['lat'].mean()
center_lon = das_fiber_all['long'].mean()

# Create folium map
m = folium.Map(location=[center_lat, center_lon], zoom_start=15, tiles='OpenStreetMap')

# Add channel markers
for _, row in das_fiber_all.iterrows():
    folium.CircleMarker(
        location=[row['lat'], row['long']],
        radius=3,
        color='blue',
        fill=True,
        fill_opacity=0.7,
        popup=f"Ch: {row['ch']}"
    ).add_to(m)


# Connect channels with a red line (fiber path)
folium.PolyLine(
    das_fiber_all[['lat', 'long']].values.tolist(),
    color='red',
    weight=2,
    opacity=0.8
).add_to(m)

# Add layer control (optional)
folium.LayerControl().add_to(m)

# Display map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_10e8cb946898d506eea3f780b4955065 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_10e8cb946898d506eea3f780b4955065&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_10e8cb946898d506eea3f780b4955065 = L.map(
#                 &quot;map_10e8cb946898d506eea3f780b4955065&quot;,
#                 {
#                     center: [37.42708544327008, -122.19267589619089],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 15,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_17db8f72dacf8a99e7e1a0dd7be9ec5f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_17db8f72dacf8a99e7e1a0dd7be9ec5f.addTo(map_10e8cb946898d506eea3f780b4955065);
#
#
#             var circle_marker_ee1490396095770ebff7eb70cee2b29c = L.circleMarker(
#                 [37.4355392208, -122.181048434],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_10e8cb946898d506eea3f780b4955065);
#
#
#         var popup_3af524a04be599889e3441828482db03 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7a069fd3943f1c54d2150c50245a21de = $(`&lt;div id=&quot;html_7a069fd3943f1c54d2150c50245a21de&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Ch: 399.0&lt;/div&gt;`)[0];
#                 popup_3af524a04be599889e3441828482db03.setContent(html_7a069fd3943f1c54d2150c50245a21de);
#
#
#
#         circle_marker_ee1490396095770ebff7eb70cee2b29c.bindPopup(popup_3af524a04be599889e3441828482db03)
#         ;
#
#
#
#
#             var circle_marker_00dca7a55146fbebc13567232586ffda = L.circleMarker(
#                 [37.4355009044, -122.181100863],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_10e8cb946898d506eea3f780b4955065);
#
#
#         var popup_28ace1a4b5784d23b5dfefe6d9c19b38 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_653cf9088014acb8567e7a268a735e43 = $(`&lt;div id=&quot;html_653cf9088014acb8567e7a268a735e43&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Ch: 400.0&lt;/div&gt;`)[0];
#                 popup_28ace1a4b5784d23b5dfefe6d9c19b38.setContent(html_653cf9088014acb8567e7a268a735e43);
#
#
#
#         circle_marker_00dca7a55146fbebc13567232586ffda.bindPopup(popup_28ace1a4b5784d23b5dfefe6d9c19b38)
#         ;
#
#
#
#
#             var circle_marker_3e631cecf525f95928694cd99348cf2c = L.circleMarker(
#                 [37.4354516739, -122.181166216],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_10e8cb946898d506eea3f780b4955065);
#
#
#         var popup_14068e14fc1106547efafa02c1bdbfeb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5b51a35b76d4e9eee5df0f36f7253212 = $(`&lt;div id=&quot;html_5b51a35b76d4e9eee5df0f36f7253212&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Ch: 401.0&lt;/div&gt;`)[0];
#                 popup_14068e14fc1106547efafa02c1bdbfeb.setContent(html_5b51a35b76d4e9eee5df0f36f7253212);
#
#
#
#         circle_marker_3e631cecf525f95928694cd99348cf2c.bindPopup(popup_14068e14fc1106547efafa02c1bdbfeb)
#         ;
#
#
#
#
#             var circle_marker_db965e5dff37891e973beb50624faa4b = L.circleMarker(
#                 [37.4353910129, -122.181246641],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: nul
